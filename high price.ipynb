# %%
# %matplotlib inline
import pandas as pd
from fbprophet import Prophet

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('BTCE-USDBTC.csv')

df.head(5)
# Out:
#          Date      High       Low    Average      Last       Buy      Sell  \
# 0  2017-05-24  2460.000  2213.000  2336.5000  2360.000  2359.999  2359.244
# 1  2017-05-23  2249.119  2017.890  2133.5045  2218.000  2218.988  2218.000
# 2  2017-05-22  2227.000  2003.794  2115.3970  2027.442  2027.442  2027.170
# 3  2017-05-21  2075.862  1960.000  2017.9310  2008.871  2014.600  2009.002
# 4  2017-05-20  1998.774  1895.670  1947.2220  1996.029  1996.042  1995.580
#
#          Volume  Volume (Currency)
# 0  2.743935e+07        11713.37874
# 1  2.419629e+07        11107.58537
# 2  3.155922e+07        14713.58743
# 3  1.559647e+07         7731.77154
# 4  1.127478e+07         5760.39916

# %%
df['Date'] = pd.DatetimeIndex(df['Date'])
df.dtypes
# Out:
# Date                 datetime64[ns]
# High                        float64
# Low                         float64
# Average                     float64
# Last                        float64
# Buy                         float64
# Sell                        float64
# Volume                      float64
# Volume (Currency)           float64
# dtype: object

# %%
df2 = df.rename(columns={'Date':'ds', 'High': 'y'})
df2.head()
# Out:
#           ds         y       Low    Average      Last       Buy      Sell  \
# 0 2017-05-24  2460.000  2213.000  2336.5000  2360.000  2359.999  2359.244
# 1 2017-05-23  2249.119  2017.890  2133.5045  2218.000  2218.988  2218.000
# 2 2017-05-22  2227.000  2003.794  2115.3970  2027.442  2027.442  2027.170
# 3 2017-05-21  2075.862  1960.000  2017.9310  2008.871  2014.600  2009.002
# 4 2017-05-20  1998.774  1895.670  1947.2220  1996.029  1996.042  1995.580
#
#          Volume  Volume (Currency)
# 0  2.743935e+07        11713.37874
# 1  2.419629e+07        11107.58537
# 2  3.155922e+07        14713.58743
# 3  1.559647e+07         7731.77154
# 4  1.127478e+07         5760.39916

# %%
df2 = df2[['ds','y']]

# %%
ax = df2.set_index('ds').plot(figsize=(12, 8))
ax.set_ylabel('Daily high usd to btc')
ax.set_xlabel('Date')

plt.show()

# %%
my_model = Prophet(interval_width=0.95)
my_model.fit(df2)

# %%
future_dates = my_model.make_future_dataframe(periods=365, freq='D')
future_dates.tail()
# Out:
#              ds
# 1821 2018-05-20
# 1822 2018-05-21
# 1823 2018-05-22
# 1824 2018-05-23
# 1825 2018-05-24

# %%
forecast = my_model.predict(future_dates)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds         yhat   yhat_lower   yhat_upper
# 1821 2018-05-20  2854.011659   989.669366  4744.647339
# 1822 2018-05-21  2866.516091   977.717387  4753.579118
# 1823 2018-05-22  2873.622801  1019.401378  4808.165573
# 1824 2018-05-23  2878.971545  1017.220587  4793.701663
# 1825 2018-05-24  2882.868357   994.336851  4775.445640

# %%
my_model.plot(forecast,
              uncertainty=True)

# %%
my_model.plot_components(forecast)
