# %%
# %matplotlib inline
import pandas as pd
from fbprophet import Prophet

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('etherprice.csv')

df.head(5)
# Out:
#          unix      date    y
# 0  1438214400  07/30/15  0.0
# 1  1438300800  07/31/15  0.0
# 2  1438387200  08/01/15  0.0
# 3  1438473600  08/02/15  0.0
# 4  1438560000  08/03/15  0.0

# %%
df.dtypes
# Out:
# unix      int64
# date     object
# y       float64
# dtype: object

# %%
df['date'] = pd.DatetimeIndex(df['date'])
df.dtypes
# Out:
# unix             int64
# date    datetime64[ns]
# y              float64
# dtype: object

# %%
df = df.rename(columns={'date': 'ds'})

df.head(5)
# Out:
#          unix         ds    y
# 0  1438214400 2015-07-30  0.0
# 1  1438300800 2015-07-31  0.0
# 2  1438387200 2015-08-01  0.0
# 3  1438473600 2015-08-02  0.0
# 4  1438560000 2015-08-03  0.0

# %%
df1 = df[['ds','y']]

# %%
ax = df1.set_index('ds').plot(figsize=(12, 8))
ax.set_ylabel('Dailit btc to usd')
ax.set_xlabel('Date')

plt.show()

# %%
my_model = Prophet(interval_width=0.95)

# %%
my_model.fit(df1)
# Out:
# Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
future_dates = my_model.make_future_dataframe(periods=365, freq='D')
future_dates.tail()
# Out:
#              ds
# 1025 2018-05-20
# 1026 2018-05-21
# 1027 2018-05-22
# 1028 2018-05-23
# 1029 2018-05-24

# %%
forecast = my_model.predict(future_dates)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds        yhat  yhat_lower  yhat_upper
# 1025 2018-05-20  336.422708  247.886966  423.322000
# 1026 2018-05-21  337.082708  248.234241  425.037740
# 1027 2018-05-22  337.748211  249.407952  427.303111
# 1028 2018-05-23  338.824096  251.500756  428.180276
# 1029 2018-05-24  338.870267  247.534045  425.887927

# %%
my_model.plot(forecast,
              uncertainty=True)

# %%
my_model.plot_components(forecast)
