# %%
# %matplotlib inline
import pandas as pd
from fbprophet import Prophet

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('https://www.quandl.com/api/v3/datasets/BTCE/USDBTC.csv?api_key=38EgYnF2uQdTsv6xLQZJ')

df.head(5)
# Out:
#          Date      High       Low    Average      Last       Buy      Sell  \
# 0  2017-06-05  2626.201  2458.400  2542.3005  2623.999  2623.999  2621.002
# 1  2017-06-04  2505.000  2409.991  2457.4955  2467.120  2468.698  2468.175
# 2  2017-06-03  2498.002  2357.000  2427.5010  2479.892  2479.896  2479.892
# 3  2017-06-02  2388.115  2300.000  2344.0575  2389.000  2389.000  2388.009
# 4  2017-06-01  2382.523  2204.106  2293.3145  2303.700  2303.650  2303.000
#
#          Volume  Volume (Currency)
# 0  1.460556e+07         5731.62652
# 1  1.229963e+07         4970.49437
# 2  1.376082e+07         5661.23893
# 3  1.027176e+07         4380.86370
# 4  2.171795e+07         9356.08810

# %%
df['Date'] = pd.DatetimeIndex(df['Date'])
df.dtypes
# Out:
# Date                 datetime64[ns]
# High                        float64
# Low                         float64
# Average                     float64
# Last                        float64
# Buy                         float64
# Sell                        float64
# Volume                      float64
# Volume (Currency)           float64
# dtype: object

# %%
df2 = df.rename(columns={'Date':'ds', 'Low': 'y'})
df2.head()
# Out:
#           ds      High         y    Average      Last       Buy      Sell  \
# 0 2017-06-05  2626.201  2458.400  2542.3005  2623.999  2623.999  2621.002
# 1 2017-06-04  2505.000  2409.991  2457.4955  2467.120  2468.698  2468.175
# 2 2017-06-03  2498.002  2357.000  2427.5010  2479.892  2479.896  2479.892
# 3 2017-06-02  2388.115  2300.000  2344.0575  2389.000  2389.000  2388.009
# 4 2017-06-01  2382.523  2204.106  2293.3145  2303.700  2303.650  2303.000
#
#          Volume  Volume (Currency)
# 0  1.460556e+07         5731.62652
# 1  1.229963e+07         4970.49437
# 2  1.376082e+07         5661.23893
# 3  1.027176e+07         4380.86370
# 4  2.171795e+07         9356.08810

# %%
df2 = df2[['ds','y']]

# %%
ax = df2.set_index('ds').plot(figsize=(12, 8))
ax.set_ylabel('Daily low usd to btc')
ax.set_xlabel('Date')

plt.show()

# %%
my_model = Prophet(interval_width=0.95)
my_model.fit(df2)

# %%
future_dates = my_model.make_future_dataframe(periods=365, freq='D')
future_dates.tail()
# Out:
#              ds
# 1833 2018-06-01
# 1834 2018-06-02
# 1835 2018-06-03
# 1836 2018-06-04
# 1837 2018-06-05

# %%
forecast = my_model.predict(future_dates)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds         yhat   yhat_lower   yhat_upper
# 1833 2018-06-01  3180.630518  1285.765868  5207.789514
# 1834 2018-06-02  3182.384884  1296.434485  5272.999856
# 1835 2018-06-03  3186.059295  1307.228667  5335.574894
# 1836 2018-06-04  3192.438123  1280.833906  5266.058615
# 1837 2018-06-05  3192.683883  1295.265405  5268.496105

# %%
my_model.plot(forecast,
              uncertainty=True)

# %%
my_model.plot_components(forecast)
